# %%
#importar a base de dados usando a biblioteca pandas
import pandas as pd
import matplotlib.pyplot as plt
from pandas.compat.numpy import np_datetime64_compat
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
#retorna um dado especifico ou aleatorio do banco de dados
dados.sample()
# Out:
#                        Rua                 Bairro     Cidade  Metragem  \
# 7071  Rua das Guassatungas  Vila Parque Jabaquara  São Paulo        63
#
#       Quartos  Banheiros  Vagas       Valor
# 7071        2          1      1  R$ 390.000

# %%
# retorna uma coluna
dados["Bairro"][6522]
# Out:
# 'Vila Paulo Silas'

# %%
#retornar informaçoes do data frame
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
#retorna a media da uma coluna
#dados.Metragem.mean()
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
sum((dados["Bairro"] == "Vila Mariana"))
# Out:
# 184

# %%
#salvando em uma variavel todos os dados encotrados  na musica
tem_imoveis_vila =( dados["Bairro"] == "Vila Mariana")
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
# retorna a contagem de valores que se repetem em uma coluna do 
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
#cria um grafico de barra com os 10 bairros que mais possuem casas
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()

# %% [markdown]
# DESAFIO:

# %% [markdown]
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)

# %%
mediabairro = dados.groupby('Bairro')['Metragem'].mean()
mediabairro.head(10)
# Out:
# Bairro
# Aclimação                    253.056818
# Alto da Boa Vista            418.875000
# Alto da Lapa                 294.337209
# Alto da Mooca                270.050000
# Alto de Pinheiros            433.444988
# Aricanduva                   278.000000
# Balneário Mar Paulista       250.000000
# Barra Funda                  135.444444
# Barro Branco (Zona Norte)    489.000000
# Bela Aliança                 345.476190
# Name: Metragem, dtype: float64

# %% [markdown]
# 2- 2 formas de selecionar os dados por bairro

# %%
dados['Bairro']
# Out:
# 0         Planalto Paulista
# 1        Jardim dos Estados
# 2           Jardim Reimberg
# 3            Jardim Morumbi
# 4                     Mooca
#                 ...
# 10003            Vila Sofia
# 10004       Bosque da Saúde
# 10005         Vila da Saúde
# 10006         Vila Oratório
# 10007           Vila Alpina
# Name: Bairro, Length: 10008, dtype: object

# %%
dados.Bairro
# Out:
# 0         Planalto Paulista
# 1        Jardim dos Estados
# 2           Jardim Reimberg
# 3            Jardim Morumbi
# 4                     Mooca
#                 ...
# 10003            Vila Sofia
# 10004       Bosque da Saúde
# 10005         Vila da Saúde
# 10006         Vila Oratório
# 10007           Vila Alpina
# Name: Bairro, Length: 10008, dtype: object

# %% [markdown]
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão

# %%
df2 = dados.plot()

# %% [markdown]
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max

# %%
dados['Metragem'].min()
# Out:
# 10

# %%
dados['Metragem'].max()
# Out:
# 750000

# %%
dados['Metragem'].median()
# Out:
# 290.0

# %%
dados.describe()
# Out:
#             Metragem       Quartos     Banheiros         Vagas
# count   10008.000000  10008.000000  10008.000000  10008.000000
# mean      442.300659      3.483114      3.879097      4.097222
# std      7515.379389      1.064200      1.988467      2.824014
# min        10.000000      1.000000      1.000000      1.000000
# 25%       173.000000      3.000000      2.000000      2.000000
# 50%       290.000000      3.000000      4.000000      4.000000
# 75%       460.250000      4.000000      5.000000      5.000000
# max    750000.000000     16.000000     40.000000     50.000000

# %% [markdown]
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
enderecoVazio=dados.Rua.isnull()
enderecoVazio = dados['Bairro'][enderecoVazio].value_counts()
enderecoVazio

# %%
dados["Bairro"] = dados["Bairro"].replace("Vila Água Funda", "Água Funda")

# %%
dados["Bairro"]
